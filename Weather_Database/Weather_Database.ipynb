# %% [markdown]
# ### Deliverable 1 Requirements

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# Import the time library and the datetime module from the datetime library 
# Starting URL for Weather Map API Call.
import time
from datetime import datetime
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a393cc2b43298c0fe7b0a22b74e4ea3

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

   # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lodja
# Processing Record 2 of Set 1 | salalah
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | sobolevo
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | hamilton
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | burica
# City not found. Skipping...
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | cayenne
# Processing Record 15 of Set 1 | kavieng
# Processing Record 16 of Set 1 | bathsheba
# Processing Record 17 of Set 1 | lesnoy
# Processing Record 18 of Set 1 | zhezkazgan
# Processing Record 19 of Set 1 | shelburne
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | kano
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | helsinki
# Processing Record 24 of Set 1 | mandalgovi
# Processing Record 25 of Set 1 | talnakh
# Processing Record 26 of Set 1 | porto novo
# Processing Record 27 of Set 1 | saint-francois
# Processing Record 28 of Set 1 | colinas
# Processing Record 29 of Set 1 | hammerfest
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | mao
# Processing Record 33 of Set 1 | mongu
# Processing Record 34 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 35 of Set 1 | henderson
# Processing Record 36 of Set 1 | san rafael
# Processing Record 37 of Set 1 | los llanos de aridane
# Processing Record 38 of Set 1 | camana
# Processing Record 39 of Set 1 | flin flon
# Processing Record 40 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | puerto escondido
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | chapais
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | sorland
# Processing Record 48 of Set 1 | sola
# Processing Record 49 of Set 1 | sabha
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | taoudenni
# Processing Record 2 of Set 2 | nhulunbuy
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | narasannapeta
# Processing Record 5 of Set 2 | ilulissat
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | acarau
# Processing Record 8 of Set 2 | geraldton
# Processing Record 9 of Set 2 | kerman
# Processing Record 10 of Set 2 | namibe
# Processing Record 11 of Set 2 | constitucion
# Processing Record 12 of Set 2 | saint-joseph
# Processing Record 13 of Set 2 | ixtapa
# Processing Record 14 of Set 2 | dongtai
# Processing Record 15 of Set 2 | dhidhdhoo
# Processing Record 16 of Set 2 | waingapu
# Processing Record 17 of Set 2 | yakuplu
# Processing Record 18 of Set 2 | cherskiy
# Processing Record 19 of Set 2 | norman wells
# Processing Record 20 of Set 2 | vestmannaeyjar
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | moyobamba
# Processing Record 23 of Set 2 | wodonga
# Processing Record 24 of Set 2 | flinders
# Processing Record 25 of Set 2 | sanming
# Processing Record 26 of Set 2 | tocopilla
# Processing Record 27 of Set 2 | dikson
# Processing Record 28 of Set 2 | aitape
# Processing Record 29 of Set 2 | bambous virieux
# Processing Record 30 of Set 2 | sungaipenuh
# Processing Record 31 of Set 2 | pandan
# Processing Record 32 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 2 | ocara
# Processing Record 34 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | pisco
# Processing Record 36 of Set 2 | caravelas
# Processing Record 37 of Set 2 | vidim
# Processing Record 38 of Set 2 | ambilobe
# Processing Record 39 of Set 2 | qaanaaq
# Processing Record 40 of Set 2 | vila franca do campo
# Processing Record 41 of Set 2 | sambava
# Processing Record 42 of Set 2 | puerto ayora
# Processing Record 43 of Set 2 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 44 of Set 2 | clyde river
# Processing Record 45 of Set 2 | oyama
# Processing Record 46 of Set 2 | garowe
# Processing Record 47 of Set 2 | beringovskiy
# Processing Record 48 of Set 2 | andenes
# Processing Record 49 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 2 | surat
# Processing Record 1 of Set 3 | fort nelson
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 3 | port lincoln
# Processing Record 4 of Set 3 | yellowknife
# Processing Record 5 of Set 3 | severo-kurilsk
# Processing Record 6 of Set 3 | tabulbah
# City not found. Skipping...
# Processing Record 7 of Set 3 | jamestown
# Processing Record 8 of Set 3 | baffa
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | karratha
# Processing Record 11 of Set 3 | ribeira brava
# Processing Record 12 of Set 3 | port blair
# Processing Record 13 of Set 3 | rio gallegos
# Processing Record 14 of Set 3 | mandera
# Processing Record 15 of Set 3 | monrovia
# Processing Record 16 of Set 3 | hobart
# Processing Record 17 of Set 3 | bonthe
# Processing Record 18 of Set 3 | saint-philippe
# Processing Record 19 of Set 3 | lokosovo
# Processing Record 20 of Set 3 | victoria
# Processing Record 21 of Set 3 | plerin
# Processing Record 22 of Set 3 | jalu
# Processing Record 23 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 3 | oussouye
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | alofi
# Processing Record 27 of Set 3 | natal
# Processing Record 28 of Set 3 | saquena
# Processing Record 29 of Set 3 | saskylakh
# Processing Record 30 of Set 3 | saint george
# Processing Record 31 of Set 3 | tessalit
# Processing Record 32 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 3 | pevek
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | pochutla
# Processing Record 36 of Set 3 | torbay
# Processing Record 37 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 3 | turochak
# Processing Record 39 of Set 3 | zhigansk
# Processing Record 40 of Set 3 | luderitz
# Processing Record 41 of Set 3 | chaozhou
# Processing Record 42 of Set 3 | saldanha
# Processing Record 43 of Set 3 | cam ranh
# Processing Record 44 of Set 3 | codrington
# Processing Record 45 of Set 3 | komsomolskiy
# Processing Record 46 of Set 3 | bereda
# Processing Record 47 of Set 3 | caucaia
# Processing Record 48 of Set 3 | conselice
# Processing Record 49 of Set 3 | atuona
# Processing Record 50 of Set 3 | saint anthony
# Processing Record 1 of Set 4 | fairbanks
# Processing Record 2 of Set 4 | itupiranga
# Processing Record 3 of Set 4 | longyearbyen
# Processing Record 4 of Set 4 | timon
# Processing Record 5 of Set 4 | coahuayana
# Processing Record 6 of Set 4 | kozelsk
# Processing Record 7 of Set 4 | isangel
# Processing Record 8 of Set 4 | lebu
# Processing Record 9 of Set 4 | nador
# Processing Record 10 of Set 4 | castro
# Processing Record 11 of Set 4 | morehead
# Processing Record 12 of Set 4 | husavik
# Processing Record 13 of Set 4 | ribeira grande
# Processing Record 14 of Set 4 | nuuk
# Processing Record 15 of Set 4 | sarakhs
# Processing Record 16 of Set 4 | san quintin
# Processing Record 17 of Set 4 | sangre grande
# Processing Record 18 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 4 | butaritari
# Processing Record 20 of Set 4 | simpang
# Processing Record 21 of Set 4 | liku
# Processing Record 22 of Set 4 | vostok
# Processing Record 23 of Set 4 | shache
# Processing Record 24 of Set 4 | puerto maldonado
# Processing Record 25 of Set 4 | chokurdakh
# Processing Record 26 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 4 | nanortalik
# Processing Record 29 of Set 4 | slovenska bistrica
# Processing Record 30 of Set 4 | nagato
# Processing Record 31 of Set 4 | kvam
# Processing Record 32 of Set 4 | kozluk
# Processing Record 33 of Set 4 | upernavik
# Processing Record 34 of Set 4 | saint-augustin
# Processing Record 35 of Set 4 | joao pessoa
# Processing Record 36 of Set 4 | port elizabeth
# Processing Record 37 of Set 4 | airai
# Processing Record 38 of Set 4 | azangaro
# Processing Record 39 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 4 | zhuhai
# Processing Record 41 of Set 4 | hanna
# Processing Record 42 of Set 4 | gat
# Processing Record 43 of Set 4 | haines junction
# Processing Record 44 of Set 4 | carnarvon
# Processing Record 45 of Set 4 | leningradskiy
# Processing Record 46 of Set 4 | pangnirtung
# Processing Record 47 of Set 4 | casablanca
# Processing Record 48 of Set 4 | manta
# Processing Record 49 of Set 4 | barrow
# Processing Record 50 of Set 4 | chuy
# Processing Record 1 of Set 5 | mwinilunga
# Processing Record 2 of Set 5 | soubre
# Processing Record 3 of Set 5 | sao filipe
# Processing Record 4 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 5 of Set 5 | klaksvik
# Processing Record 6 of Set 5 | cabo san lucas
# Processing Record 7 of Set 5 | bajos de haina
# Processing Record 8 of Set 5 | drovyanaya
# Processing Record 9 of Set 5 | kabompo
# Processing Record 10 of Set 5 | mehamn
# Processing Record 11 of Set 5 | turayf
# Processing Record 12 of Set 5 | east london
# Processing Record 13 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 5 | portland
# Processing Record 15 of Set 5 | khatanga
# Processing Record 16 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 5 | belaya kholunitsa
# Processing Record 18 of Set 5 | hendijan
# City not found. Skipping...
# Processing Record 19 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 5 | arlit
# Processing Record 21 of Set 5 | katobu
# Processing Record 22 of Set 5 | pangai
# Processing Record 23 of Set 5 | maraa
# Processing Record 24 of Set 5 | dawlatabad
# Processing Record 25 of Set 5 | mackenzie
# Processing Record 26 of Set 5 | creel
# Processing Record 27 of Set 5 | itaituba
# Processing Record 28 of Set 5 | kulhudhuffushi
# Processing Record 29 of Set 5 | swan hill
# Processing Record 30 of Set 5 | quatre cocos
# Processing Record 31 of Set 5 | leua
# Processing Record 32 of Set 5 | virginia beach
# Processing Record 33 of Set 5 | ponta do sol
# Processing Record 34 of Set 5 | benghazi
# Processing Record 35 of Set 5 | hithadhoo
# Processing Record 36 of Set 5 | moundsville
# Processing Record 37 of Set 5 | mamallapuram
# Processing Record 38 of Set 5 | arraial do cabo
# Processing Record 39 of Set 5 | nampula
# Processing Record 40 of Set 5 | yima
# Processing Record 41 of Set 5 | shibetsu
# Processing Record 42 of Set 5 | taldan
# Processing Record 43 of Set 5 | joshimath
# Processing Record 44 of Set 5 | leh
# Processing Record 45 of Set 5 | henties bay
# Processing Record 46 of Set 5 | dharmavaram
# Processing Record 47 of Set 5 | alta floresta
# Processing Record 48 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 5 | kahului
# Processing Record 50 of Set 5 | cururupu
# Processing Record 1 of Set 6 | corleone
# Processing Record 2 of Set 6 | loule
# Processing Record 3 of Set 6 | bukachacha
# Processing Record 4 of Set 6 | presidencia roque saenz pena
# Processing Record 5 of Set 6 | sao joao da barra
# Processing Record 6 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 7 of Set 6 | novosheshminsk
# Processing Record 8 of Set 6 | oriximina
# Processing Record 9 of Set 6 | mongo
# Processing Record 10 of Set 6 | cerqueira cesar
# Processing Record 11 of Set 6 | nome
# Processing Record 12 of Set 6 | jimma
# Processing Record 13 of Set 6 | marsa matruh
# Processing Record 14 of Set 6 | weinan
# Processing Record 15 of Set 6 | trelew
# Processing Record 16 of Set 6 | hokitika
# Processing Record 17 of Set 6 | bethel
# Processing Record 18 of Set 6 | esperance
# Processing Record 19 of Set 6 | mahebourg
# Processing Record 20 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 6 | dunedin
# Processing Record 22 of Set 6 | provideniya
# Processing Record 23 of Set 6 | iqaluit
# Processing Record 24 of Set 6 | notse
# Processing Record 25 of Set 6 | dingle
# Processing Record 26 of Set 6 | luang prabang
# Processing Record 27 of Set 6 | maragogi
# Processing Record 28 of Set 6 | bougouni
# Processing Record 29 of Set 6 | mocuba
# Processing Record 30 of Set 6 | agadez
# Processing Record 31 of Set 6 | monduli
# Processing Record 32 of Set 6 | idah
# Processing Record 33 of Set 6 | tuatapere
# Processing Record 34 of Set 6 | kaitangata
# Processing Record 35 of Set 6 | broken hill
# Processing Record 36 of Set 6 | hasaki
# Processing Record 37 of Set 6 | novyy chirkey
# Processing Record 38 of Set 6 | vagay
# Processing Record 39 of Set 6 | banyo
# Processing Record 40 of Set 6 | sibolga
# Processing Record 41 of Set 6 | la ronge
# Processing Record 42 of Set 6 | hofn
# Processing Record 43 of Set 6 | alice springs
# Processing Record 44 of Set 6 | gigmoto
# Processing Record 45 of Set 6 | cranbrook
# Processing Record 46 of Set 6 | samarinda
# Processing Record 47 of Set 6 | yulara
# Processing Record 48 of Set 6 | coihaique
# Processing Record 49 of Set 6 | ahipara
# Processing Record 50 of Set 6 | milingimbi
# City not found. Skipping...
# Processing Record 1 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 2 of Set 7 | kodiak
# Processing Record 3 of Set 7 | newport
# Processing Record 4 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 7 | nyuksenitsa
# Processing Record 6 of Set 7 | rawson
# Processing Record 7 of Set 7 | myskhako
# Processing Record 8 of Set 7 | zavetnoye
# Processing Record 9 of Set 7 | along
# Processing Record 10 of Set 7 | tautira
# Processing Record 11 of Set 7 | parrita
# Processing Record 12 of Set 7 | melfi
# Processing Record 13 of Set 7 | hovd
# Processing Record 14 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 15 of Set 7 | kysyl-syr
# Processing Record 16 of Set 7 | erenhot
# Processing Record 17 of Set 7 | skjervoy
# Processing Record 18 of Set 7 | uyskoye
# Processing Record 19 of Set 7 | montrose
# Processing Record 20 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 21 of Set 7 | katsuura
# Processing Record 22 of Set 7 | gidam
# Processing Record 23 of Set 7 | nachingwea
# Processing Record 24 of Set 7 | alibag
# Processing Record 25 of Set 7 | decatur
# Processing Record 26 of Set 7 | safford
# Processing Record 27 of Set 7 | wolgast
# Processing Record 28 of Set 7 | salamina
# Processing Record 29 of Set 7 | zeya
# Processing Record 30 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 7 | senador guiomard
# Processing Record 32 of Set 7 | marienburg
# Processing Record 33 of Set 7 | hay river
# Processing Record 34 of Set 7 | salinopolis
# Processing Record 35 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 7 | lavrentiya
# Processing Record 37 of Set 7 | souillac
# Processing Record 38 of Set 7 | narrabri
# Processing Record 39 of Set 7 | pimentel
# Processing Record 40 of Set 7 | cairns
# Processing Record 41 of Set 7 | gamba
# Processing Record 42 of Set 7 | lasa
# Processing Record 43 of Set 7 | ca mau
# Processing Record 44 of Set 7 | churapcha
# Processing Record 45 of Set 7 | shingu
# Processing Record 46 of Set 7 | chaohu
# Processing Record 47 of Set 7 | ordzhonikidze
# Processing Record 48 of Set 7 | mildura
# Processing Record 49 of Set 7 | vetluzhskiy
# Processing Record 50 of Set 7 | yabrud
# Processing Record 1 of Set 8 | zyryanka
# Processing Record 2 of Set 8 | cody
# Processing Record 3 of Set 8 | lushunkou
# City not found. Skipping...
# Processing Record 4 of Set 8 | gobabis
# Processing Record 5 of Set 8 | fortuna
# Processing Record 6 of Set 8 | pangody
# Processing Record 7 of Set 8 | hanting
# Processing Record 8 of Set 8 | ancud
# Processing Record 9 of Set 8 | teya
# Processing Record 10 of Set 8 | viedma
# Processing Record 11 of Set 8 | kupang
# Processing Record 12 of Set 8 | camacha
# Processing Record 13 of Set 8 | aguas vermelhas
# Processing Record 14 of Set 8 | gazanjyk
# Processing Record 15 of Set 8 | floha
# Processing Record 16 of Set 8 | nsanje
# Processing Record 17 of Set 8 | murmashi
# Processing Record 18 of Set 8 | lata
# Processing Record 19 of Set 8 | port macquarie
# Processing Record 20 of Set 8 | tokonou
# Processing Record 21 of Set 8 | mujiayingzi
# Processing Record 22 of Set 8 | juegang
# Processing Record 23 of Set 8 | buraydah
# Processing Record 24 of Set 8 | goundi
# Processing Record 25 of Set 8 | phetchabun
# Processing Record 26 of Set 8 | rantepao
# Processing Record 27 of Set 8 | soyo
# Processing Record 28 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 8 | arrecife
# Processing Record 30 of Set 8 | adrar
# Processing Record 31 of Set 8 | agen
# Processing Record 32 of Set 8 | molina
# Processing Record 33 of Set 8 | pyaozerskiy
# Processing Record 34 of Set 8 | cidreira
# Processing Record 35 of Set 8 | suffolk
# Processing Record 36 of Set 8 | nemuro
# Processing Record 37 of Set 8 | batemans bay
# Processing Record 38 of Set 8 | pingliang
# Processing Record 39 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 40 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 41 of Set 8 | seoul
# Processing Record 42 of Set 8 | phitsanulok
# Processing Record 43 of Set 8 | omboue
# Processing Record 44 of Set 8 | kendari
# Processing Record 45 of Set 8 | scarborough
# Processing Record 46 of Set 8 | camanci
# City not found. Skipping...
# Processing Record 47 of Set 8 | prado
# Processing Record 48 of Set 8 | najran
# Processing Record 49 of Set 8 | sid
# Processing Record 50 of Set 8 | lagoa
# Processing Record 1 of Set 9 | sayyan
# Processing Record 2 of Set 9 | yaan
# Processing Record 3 of Set 9 | khasan
# Processing Record 4 of Set 9 | shiraz
# Processing Record 5 of Set 9 | grafton
# Processing Record 6 of Set 9 | sistranda
# Processing Record 7 of Set 9 | kidal
# Processing Record 8 of Set 9 | vilhena
# Processing Record 9 of Set 9 | cap malheureux
# Processing Record 10 of Set 9 | ylivieska
# Processing Record 11 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 12 of Set 9 | faanui
# Processing Record 13 of Set 9 | xinzhou
# Processing Record 14 of Set 9 | zlitan
# Processing Record 15 of Set 9 | oranjestad
# Processing Record 16 of Set 9 | te anau
# Processing Record 17 of Set 9 | redcliffe
# Processing Record 18 of Set 9 | luena
# Processing Record 19 of Set 9 | copiapo
# Processing Record 20 of Set 9 | tarko-sale
# Processing Record 21 of Set 9 | comarapa
# Processing Record 22 of Set 9 | yorkton
# Processing Record 23 of Set 9 | ewa beach
# Processing Record 24 of Set 9 | kleck
# City not found. Skipping...
# Processing Record 25 of Set 9 | mirnyy
# Processing Record 26 of Set 9 | doda
# Processing Record 27 of Set 9 | praia
# Processing Record 28 of Set 9 | tillabery
# City not found. Skipping...
# Processing Record 29 of Set 9 | garoua
# Processing Record 30 of Set 9 | lakes entrance
# Processing Record 31 of Set 9 | coquimbo
# Processing Record 32 of Set 9 | shagamu
# Processing Record 33 of Set 9 | lompoc
# Processing Record 34 of Set 9 | buala
# Processing Record 35 of Set 9 | nizhniy odes
# Processing Record 36 of Set 9 | avera
# Processing Record 37 of Set 9 | anchorage
# Processing Record 38 of Set 9 | shibarghan
# City not found. Skipping...
# Processing Record 39 of Set 9 | sanandaj
# Processing Record 40 of Set 9 | winneba
# Processing Record 41 of Set 9 | sergeyevka
# Processing Record 42 of Set 9 | talara
# Processing Record 43 of Set 9 | coracao de jesus
# Processing Record 44 of Set 9 | morondava
# Processing Record 45 of Set 9 | mizan teferi
# Processing Record 46 of Set 9 | coos bay
# Processing Record 47 of Set 9 | tatawin
# Processing Record 48 of Set 9 | puttur
# Processing Record 49 of Set 9 | pocone
# Processing Record 50 of Set 9 | mount gambier
# Processing Record 1 of Set 10 | bandar
# Processing Record 2 of Set 10 | necochea
# Processing Record 3 of Set 10 | yebaishou
# Processing Record 4 of Set 10 | hambantota
# Processing Record 5 of Set 10 | kuruksay
# City not found. Skipping...
# Processing Record 6 of Set 10 | vanimo
# Processing Record 7 of Set 10 | lorengau
# Processing Record 8 of Set 10 | isilkul
# Processing Record 9 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 10 of Set 10 | whitehorse
# Processing Record 11 of Set 10 | beipiao
# Processing Record 12 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 10 | luorong
# Processing Record 14 of Set 10 | berlevag
# Processing Record 15 of Set 10 | san ramon
# Processing Record 16 of Set 10 | matsanga
# City not found. Skipping...
# Processing Record 17 of Set 10 | setermoen
# Processing Record 18 of Set 10 | maridi
# Processing Record 19 of Set 10 | at-bashi
# Processing Record 20 of Set 10 | casa nova
# Processing Record 21 of Set 10 | pinotepa nacional
# Processing Record 22 of Set 10 | road town
# Processing Record 23 of Set 10 | karema
# Processing Record 24 of Set 10 | kisangani
# Processing Record 25 of Set 10 | puerto narino
# Processing Record 26 of Set 10 | gusau
# Processing Record 27 of Set 10 | naze
# Processing Record 28 of Set 10 | san policarpo
# Processing Record 29 of Set 10 | vardo
# Processing Record 30 of Set 10 | priiskovyy
# Processing Record 31 of Set 10 | campbell river
# Processing Record 32 of Set 10 | conde
# Processing Record 33 of Set 10 | sidareja
# Processing Record 34 of Set 10 | bengkulu
# Processing Record 35 of Set 10 | shimoda
# Processing Record 36 of Set 10 | olinda
# Processing Record 37 of Set 10 | marquette
# Processing Record 38 of Set 10 | yeppoon
# Processing Record 39 of Set 10 | gander
# Processing Record 40 of Set 10 | high rock
# Processing Record 41 of Set 10 | rovaniemi
# Processing Record 42 of Set 10 | north branch
# Processing Record 43 of Set 10 | shchelkun
# Processing Record 44 of Set 10 | yuxia
# Processing Record 45 of Set 10 | chimoio
# Processing Record 46 of Set 10 | sitka
# Processing Record 47 of Set 10 | cochrane
# Processing Record 48 of Set 10 | maceio
# Processing Record 49 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 50 of Set 10 | broome
# Processing Record 1 of Set 11 | tanete
# Processing Record 2 of Set 11 | halifax
# Processing Record 3 of Set 11 | potosi
# Processing Record 4 of Set 11 | itarema
# Processing Record 5 of Set 11 | burns lake
# Processing Record 6 of Set 11 | port hardy
# Processing Record 7 of Set 11 | champerico
# Processing Record 8 of Set 11 | peno
# Processing Record 9 of Set 11 | guerrero negro
# Processing Record 10 of Set 11 | vanavara
# Processing Record 11 of Set 11 | aleksandrov gay
# Processing Record 12 of Set 11 | korla
# Processing Record 13 of Set 11 | jinxiang
# Processing Record 14 of Set 11 | chegdomyn
# Processing Record 15 of Set 11 | grindavik
# Processing Record 16 of Set 11 | saint marys
# Processing Record 17 of Set 11 | puerto madero
# Processing Record 18 of Set 11 | umm jarr
# City not found. Skipping...
# Processing Record 19 of Set 11 | salamiyah
# Processing Record 20 of Set 11 | fernley
# Processing Record 21 of Set 11 | noumea
# Processing Record 22 of Set 11 | maldonado
# Processing Record 23 of Set 11 | sompeta
# Processing Record 24 of Set 11 | touho
# Processing Record 25 of Set 11 | santiago del estero
# Processing Record 26 of Set 11 | olafsvik
# Processing Record 27 of Set 11 | peleduy
# Processing Record 28 of Set 11 | miles city
# Processing Record 29 of Set 11 | tiznit
# Processing Record 30 of Set 11 | balykshi
# Processing Record 31 of Set 11 | sohag
# Processing Record 32 of Set 11 | irituia
# Processing Record 33 of Set 11 | shu
# Processing Record 34 of Set 11 | livani
# Processing Record 35 of Set 11 | moerai
# Processing Record 36 of Set 11 | nouadhibou
# Processing Record 37 of Set 11 | tamandare
# Processing Record 38 of Set 11 | hermosillo
# Processing Record 39 of Set 11 | babu
# Processing Record 40 of Set 11 | elko
# Processing Record 41 of Set 11 | kununurra
# Processing Record 42 of Set 11 | tahoua
# Processing Record 43 of Set 11 | chumikan
# Processing Record 44 of Set 11 | sao miguel do araguaia
# Processing Record 45 of Set 11 | tiksi
# Processing Record 46 of Set 11 | valparai
# Processing Record 47 of Set 11 | haysville
# Processing Record 48 of Set 11 | labuhan
# Processing Record 49 of Set 11 | moindou
# Processing Record 50 of Set 11 | masuguru
# Processing Record 1 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 12 | laguna
# Processing Record 3 of Set 12 | red bluff
# Processing Record 4 of Set 12 | tura
# Processing Record 5 of Set 12 | reynosa
# Processing Record 6 of Set 12 | tecoanapa
# Processing Record 7 of Set 12 | williston
# Processing Record 8 of Set 12 | san juan
# Processing Record 9 of Set 12 | juneau
# Processing Record 10 of Set 12 | imbituba
# Processing Record 11 of Set 12 | yantzaza
# Processing Record 12 of Set 12 | fare
# Processing Record 13 of Set 12 | tignere
# Processing Record 14 of Set 12 | kamaishi
# Processing Record 15 of Set 12 | emerald
# Processing Record 16 of Set 12 | kankaanpaa
# Processing Record 17 of Set 12 | rio grande
# Processing Record 18 of Set 12 | skegness
# Processing Record 19 of Set 12 | pacific grove
# Processing Record 20 of Set 12 | chaihe
# Processing Record 21 of Set 12 | axim
# Processing Record 22 of Set 12 | namatanai
# Processing Record 23 of Set 12 | aklavik
# Processing Record 24 of Set 12 | rypefjord
# Processing Record 25 of Set 12 | parambu
# Processing Record 26 of Set 12 | chato
# Processing Record 27 of Set 12 | saint-pierre
# Processing Record 28 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 12 | minna
# Processing Record 30 of Set 12 | robe
# Processing Record 31 of Set 12 | fomboni
# Processing Record 32 of Set 12 | agogo
# Processing Record 33 of Set 12 | san andres
# Processing Record 34 of Set 12 | maunabo
# Processing Record 35 of Set 12 | alamosa
# Processing Record 36 of Set 12 | myitkyina
# Processing Record 37 of Set 12 | san cristobal
# Processing Record 38 of Set 12 | gweru
# Processing Record 39 of Set 12 | bang saphan
# Processing Record 40 of Set 12 | chernyshevskiy
# Processing Record 41 of Set 12 | tibati
# Processing Record 42 of Set 12 | mwense
# Processing Record 43 of Set 12 | nicoya
# Processing Record 44 of Set 12 | evinayong
# Processing Record 45 of Set 12 | dingzhou
# Processing Record 46 of Set 12 | evensk
# Processing Record 47 of Set 12 | iwanai
# Processing Record 48 of Set 12 | betanzos
# Processing Record 49 of Set 12 | gelgaudiskis
# Processing Record 50 of Set 12 | lake lucerne
# Processing Record 1 of Set 13 | samarai
# Processing Record 2 of Set 13 | ayr
# Processing Record 3 of Set 13 | hurghada
# Processing Record 4 of Set 13 | deputatskiy
# Processing Record 5 of Set 13 | launceston
# Processing Record 6 of Set 13 | mayumba
# Processing Record 7 of Set 13 | port-gentil
# Processing Record 8 of Set 13 | kashi
# Processing Record 9 of Set 13 | idukki
# Processing Record 10 of Set 13 | touros
# Processing Record 11 of Set 13 | nioki
# Processing Record 12 of Set 13 | harper
# Processing Record 13 of Set 13 | tchibanga
# Processing Record 14 of Set 13 | birao
# Processing Record 15 of Set 13 | ada
# Processing Record 16 of Set 13 | arroyo
# Processing Record 17 of Set 13 | trapani
# Processing Record 18 of Set 13 | ucluelet
# Processing Record 19 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 20 of Set 13 | kirakira
# Processing Record 21 of Set 13 | mahibadhoo
# Processing Record 22 of Set 13 | araouane
# Processing Record 23 of Set 13 | villa carlos paz
# Processing Record 24 of Set 13 | kyshtovka
# Processing Record 25 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 13 | magistralnyy
# Processing Record 27 of Set 13 | san carlos del zulia
# Processing Record 28 of Set 13 | rudnichnyy
# Processing Record 29 of Set 13 | juan lacaze
# Processing Record 30 of Set 13 | cabedelo
# Processing Record 31 of Set 13 | comodoro rivadavia
# Processing Record 32 of Set 13 | kieta
# Processing Record 33 of Set 13 | hohhot
# Processing Record 34 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 35 of Set 13 | abeche
# Processing Record 36 of Set 13 | boden
# Processing Record 37 of Set 13 | sinnamary
# Processing Record 38 of Set 13 | amahai
# Processing Record 39 of Set 13 | egvekinot
# Processing Record 40 of Set 13 | banjar
# Processing Record 41 of Set 13 | tingrela
# City not found. Skipping...
# Processing Record 42 of Set 13 | guozhen
# Processing Record 43 of Set 13 | ketchenery
# City not found. Skipping...
# Processing Record 44 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 45 of Set 13 | peniche
# Processing Record 46 of Set 13 | dire
# Processing Record 47 of Set 13 | verkhoyansk
# Processing Record 48 of Set 13 | himora
# City not found. Skipping...
# Processing Record 49 of Set 13 | guilin
# Processing Record 50 of Set 13 | kralendijk
# Processing Record 1 of Set 14 | balakovo
# Processing Record 2 of Set 14 | richards bay
# Processing Record 3 of Set 14 | fort frances
# Processing Record 4 of Set 14 | tongzhou
# Processing Record 5 of Set 14 | senno
# Processing Record 6 of Set 14 | flores costa cuca
# Processing Record 7 of Set 14 | charters towers
# Processing Record 8 of Set 14 | beyla
# Processing Record 9 of Set 14 | kurtalan
# Processing Record 10 of Set 14 | ola
# Processing Record 11 of Set 14 | nelson bay
# Processing Record 12 of Set 14 | stepnyak
# Processing Record 13 of Set 14 | salcedo
# Processing Record 14 of Set 14 | tucupita
# Processing Record 15 of Set 14 | senmonorom
# City not found. Skipping...
# Processing Record 16 of Set 14 | murgab
# Processing Record 17 of Set 14 | kasempa
# Processing Record 18 of Set 14 | villamontes
# Processing Record 19 of Set 14 | ulladulla
# Processing Record 20 of Set 14 | lahaina
# Processing Record 21 of Set 14 | hermiston
# Processing Record 22 of Set 14 | ayan
# Processing Record 23 of Set 14 | kokopo
# Processing Record 24 of Set 14 | bull savanna
# Processing Record 25 of Set 14 | piacabucu
# Processing Record 26 of Set 14 | uvira
# Processing Record 27 of Set 14 | los algarrobos
# Processing Record 28 of Set 14 | vila velha
# Processing Record 29 of Set 14 | batsfjord
# Processing Record 30 of Set 14 | vao
# Processing Record 31 of Set 14 | jasper
# Processing Record 32 of Set 14 | faya
# Processing Record 33 of Set 14 | dali
# Processing Record 34 of Set 14 | bilma
# Processing Record 35 of Set 14 | union
# Processing Record 36 of Set 14 | tambura
# Processing Record 37 of Set 14 | pandan niog
# Processing Record 38 of Set 14 | bandar-e lengeh
# Processing Record 39 of Set 14 | loubomo
# Processing Record 40 of Set 14 | manado
# Processing Record 41 of Set 14 | isla mujeres
# Processing Record 42 of Set 14 | lahat
# Processing Record 43 of Set 14 | baykit
# Processing Record 44 of Set 14 | abu dhabi
# Processing Record 45 of Set 14 | luza
# Processing Record 46 of Set 14 | tukrah
# Processing Record 47 of Set 14 | felanitx
# Processing Record 48 of Set 14 | kruisfontein
# Processing Record 49 of Set 14 | matthews
# Processing Record 50 of Set 14 | eureka
# Processing Record 1 of Set 15 | satun
# Processing Record 2 of Set 15 | chunoyar
# Processing Record 3 of Set 15 | naron
# Processing Record 4 of Set 15 | yuryevets
# Processing Record 5 of Set 15 | pitimbu
# Processing Record 6 of Set 15 | bowen
# Processing Record 7 of Set 15 | pemangkat
# Processing Record 8 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 9 of Set 15 | padron
# Processing Record 10 of Set 15 | quimperle
# Processing Record 11 of Set 15 | kavaratti
# Processing Record 12 of Set 15 | concordia
# Processing Record 13 of Set 15 | tezu
# Processing Record 14 of Set 15 | daimiel
# Processing Record 15 of Set 15 | chalus
# Processing Record 16 of Set 15 | paracuru
# Processing Record 17 of Set 15 | san patricio
# Processing Record 18 of Set 15 | guelengdeng
# City not found. Skipping...
# Processing Record 19 of Set 15 | inongo
# Processing Record 20 of Set 15 | iquitos
# Processing Record 21 of Set 15 | huarmey
# Processing Record 22 of Set 15 | dolores
# Processing Record 23 of Set 15 | vitry-le-francois
# Processing Record 24 of Set 15 | kenai
# Processing Record 25 of Set 15 | nyurba
# Processing Record 26 of Set 15 | kosa
# Processing Record 27 of Set 15 | inhambane
# Processing Record 28 of Set 15 | nezhinka
# Processing Record 29 of Set 15 | malakal
# Processing Record 30 of Set 15 | atagay
# Processing Record 31 of Set 15 | bo phloi
# Processing Record 32 of Set 15 | vestmanna
# Processing Record 33 of Set 15 | mandiana
# Processing Record 34 of Set 15 | takab
# Processing Record 35 of Set 15 | aranos
# Processing Record 36 of Set 15 | saiha
# Processing Record 37 of Set 15 | kimovsk
# Processing Record 38 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 15 | gap
# Processing Record 40 of Set 15 | reitz
# Processing Record 41 of Set 15 | teguldet
# Processing Record 42 of Set 15 | khani
# Processing Record 43 of Set 15 | poum
# Processing Record 44 of Set 15 | buluang
# Processing Record 45 of Set 15 | balimo
# City not found. Skipping...
# Processing Record 46 of Set 15 | whithorn
# Processing Record 47 of Set 15 | palmer
# Processing Record 48 of Set 15 | narsaq
# Processing Record 49 of Set 15 | catuday
# Processing Record 50 of Set 15 | mangrol
# Processing Record 1 of Set 16 | grand gaube
# Processing Record 2 of Set 16 | panaba
# Processing Record 3 of Set 16 | bandarbeyla
# Processing Record 4 of Set 16 | sur
# Processing Record 5 of Set 16 | moberly
# Processing Record 6 of Set 16 | annau
# Processing Record 7 of Set 16 | tilichiki
# Processing Record 8 of Set 16 | ostersund
# Processing Record 9 of Set 16 | farafangana
# Processing Record 10 of Set 16 | port-cartier
# Processing Record 11 of Set 16 | innisfail
# Processing Record 12 of Set 16 | svetlyy
# Processing Record 13 of Set 16 | la malbaie
# Processing Record 14 of Set 16 | sept-iles
# Processing Record 15 of Set 16 | santa quiteria do maranhao
# Processing Record 16 of Set 16 | agadir
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Lodja      CD  -3.4833   23.4333     75.56        74          87
# 1       Salalah      OM  17.0151   54.0924     84.29        84          75
# 2  Punta Arenas      CL -53.1500  -70.9167     39.31        70          40
# 3      Hermanus      ZA -34.4187   19.2345     60.53        86          37
# 4   Port Alfred      ZA -33.5906   26.8910     56.17        93          33
# 5      Sobolevo      RU  54.4299   31.8996     44.96        73          61
# 6   New Norfolk      AU -42.7826  147.0587     49.91        82          94
# 7        Albany      US  42.6001  -73.9662     91.44        48          61
# 8      Hamilton      US  39.1834  -84.5333     67.19        75         100
# 9       Mataura      NZ -46.1927  168.8643     44.26        92         100
#
#    Wind Speed Current Description
# 0        0.36     overcast clouds
# 1        9.22       broken clouds
# 2        9.22    scattered clouds
# 3        8.28    scattered clouds
# 4        3.13    scattered clouds
# 5        6.35       broken clouds
# 6        2.51     overcast clouds
# 7        1.01       broken clouds
# 8       12.66     overcast clouds
# 9        7.23     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
